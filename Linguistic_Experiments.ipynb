# %%
import json

# f = open('General_internal_med_claims_from_300_abs.json')
# Med_data = json.load(f)

# f.close()

g = open('Biotechnology_claims_from_300_abs.json')
Bio_data = json.load(g)

g.close()

# %%
bio_list = []
med_list = []

for dictionary in range(0, len(Bio_data)):
        
        for key, value in Bio_data[dictionary]["sentences"].items():

            if value == "CLAIM" or value == "EVIDENCE" or value == "NONE":

                bio_list.append(key)


print(len(bio_list))
print(type(bio_list))
print(bio_list)

# for dictionary in range(0, len(Med_data)):
        
#         for key, value in Med_data[dictionary]["sentences"].items():

#             if value == "CLAIM" or value == "EVIDENCE" or value == "NONE":

#                 med_list.append(key)

# print(len(med_list))
# print(type(med_list))
# print(med_list)

# %%
new_list = " ".join(bio_list).split(" ")

# %%
# Tool for calculating modality of sentences
# List of common modality markers
modals_markers = {
    "high": ["can", "cannot", "can't", "have to", "has to", "must", "need to", "needs to", "will", "won't"],
    "medium": ["ought to", "should", "would"],
    "low": ["could", "may", "might"]
}

modifiers_markers = {
    "high": ["by no means", "certainly", "definitely", "doubtless", "for certain", "for sure", "incontestably", "incontrovertibly", "indisputably", "indubitably",
             "no doubt", "on no account", "surely", "unarguably", "undeniably", "undoubtedly", "unquestionably", "without a doubt"],
    "medium": ["arguably", "in all likelihood", "most likely", "likely", "presumably", "probably", "supposedly"],
    "low": ["allegedly ", "conceivably", "maybe", "perhaps", "possibly", "purportedly "]
}

adjectives_markers = {
    "high": ["certain", "impossible", "inconceivable", "not possible", "sure", "certain", "undeniable", "convinced"],
    "medium": ["plausible", "probable", "most likely", "likely"],
    "low": ["conceivable ", "doubtful", "not likely", "possible", "uncertain", "unlikely"]
}

nouns_markers = {
    "high": ["little doubt", "no doubt"],
    "medium": ["likelihood", "feeling", "impression"],
    "low": ["doubts ", "possibility"]
}

verbs_markers = {
    "high": [],
    "medium": ["assumed", "believed", "expected", "supposed", "thought", "assume", "believe", "expect", "imagine", "presume", "suppose", "think", "it appears", "it seems",
               "assume", "believe", "expect", "imagine", "presume", "suppose", "think"],
    "low": ["speculated ", "suspected", "doubt", "guess", "speculate", "suspect"]
}

# Function to detect modality
def detect_modality(med_list):
    tokens = new_list
    detected = {category: [word for word in tokens if word in words] for category, words in verbs_markers.items()}
    return detected

sentence = """Pseudomonas brassicacearum DF41 is a biocontrol agent that suppresses disease caused by the fungal pathogen Sclerotinia sclerotiorum . A number of exometabolites are produced by DF41, including the lipopeptide sclerosin, hydrogen cyanide (HCN), and degradative enzymes. The production of these compounds is controlled at both the transcriptional and posttranscriptional levels by quorum sensing (QS) and the Gac two-component regulatory system. In order to be successful, a biocontrol agent must persist in the environment at levels sufficient for pathogen control. Bacterivorous predators, including nematodes, represent a challenge to the establishment of introduced microorganisms. In the current study, DF41 was investigated for its ability to resist predation by Caenorhabditis elegans . We discovered that this bacterium is capable of killing C. elegans through two different mech
# %%
import nltk
from nltk import pos_tag
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def extract_verbs(text):
    words = word_tokenize(text)
    tagged_words = pos_tag(words)
    
    verbs = [word for word, tag in tagged_words if tag.startswith('MD')]
    
    return verbs

# Example usage:
text = """Troy as seen in Homer's account is probably true in part. However, it is wrong to think his account is historically exact. With that warning, this is a summary of events leading up to the Trojan war, mostly derived from the Iliad. Troy was a powerful kingdom in the Mediterranean sea, and thrived under the long rule of King Priam. His many sons, including the valiant, strong, unbeatable Hector, and Paris, a creative character who was not a strong fighter but a passionate man, are the best known in the Troy myth. 
In Greece lay a Kingdom called Mycene, owned by Mycenaean or Mykene people, ruled by King Agamemnon. He started a campaign to pressure the Greece cities or kingdoms and to join him and attack Troy, to capture its many riches. The King of Ithaca, Odysseus (or Ulysses, as he was also known), along with King Idomenous of Crete, with up to 22 more Kingdoms and Kings, spent ten years attacking Troy. Eventually, Troy fell after a coup that Odysseus had thought up, using a wooden trojan horse to hide soldiers within in order to get soldiers behind the Trojan line of defence.
Before the fall of Troy, during the dawn of the War, King Priam sought to create an alliance with the strong Kingdom of Sparta in Northern Greece, to defend Troy when the war had begun. King Aeneas, or Helikaon as he was said to be known, King of Dardanos, was a good friend of Hektor and King Priam, and sided with the Trojans in the war. Unfortunately, on the journey back, after Hektor and Paris had forged an alliance in Sparta, Paris took the wife of the King of Sparta, Princess Helen, without his consent, as they had fallen in love. This ended the alliance,and Sparta eventually joined the fighting cause of King Agammenon."""
# text = "I love coding, and I enjoy learning new programming languages."
result = extract_verbs(text)
print("Verbs:", result)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\uc_ma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\uc_ma\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Verbs: []

# %%
med_verbs = []

for sentence in range(0, len(med_list)):
    verbs_list = extract_verbs(med_list[sentence])

    for verb in verbs_list:
        med_verbs.append(verb)


bio_verbs = []

for sentence in range(0, len(bio_list)):
    verbs_list = extract_verbs(bio_list[sentence])

    for verb in verbs_list:
        bio_verbs.append(verb)

print(bio_verbs)
print(med_verbs)
# Out:
# ['could', 'could', 'could', 'could', 'can', 'will', 'may', 'can', 'will', 'may', 'could', 'could', 'can', 'can', 'should', 'could', 'can', 'might', 'may', 'will', 'would', 'will', 'could', 'will', 'can', 'would', 'might', 'can', 'could', 'can', 'could', 'can', 'could', 'could', 'could', 'can', 'can', 'could', 'could', 'can', 'can', 'can', 'could', 'can', 'can', 'could', 'would', 'must', 'can', 'can', 'will', 'can', 'may', 'can', 'can', 'can', 'will', 'may', 'can', 'can', 'could', 'could', 'may', 'will', 'can', 'could', 'can', 'can', 'can', 'could', 'will', 'can', 'can', 'could', 'could', 'could', 'should', 'can', 'could', 'will']
# ...

# %%
wordfreq_1_bio = {}
for raw_word in bio_verbs:

    if raw_word not in wordfreq_1_bio:
        wordfreq_1_bio[raw_word] = 0
    wordfreq_1_bio[raw_word] += 1


wordfreq_2_med = {}
for raw_word in med_verbs:
    if raw_word not in wordfreq_2_med:
        wordfreq_2_med[raw_word] = 0
    wordfreq_2_med[raw_word] += 1

# %%
type2freq_1 = wordfreq_1_bio
type2freq_2 = wordfreq_2_med

# %%
# MODALS

import shifterator as sh

proportion_shift = sh.ProportionShift(type2freq_1=type2freq_1,
                                      type2freq_2=type2freq_2)

proportion_shift.get_shift_graph(system_names = ['Biotechnology', 'Medicine'],
                                 title='Biotechnology vs General Medicine')
# Out:
# c:\Users\uc_ma\AppData\Local\Programs\Python\Python38\lib\site-packages\shifterator\plotting.py:604: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x_ticks, fontsize=plot_params["xtick_fontsize"])
# <AxesSubplot:title={'center':'Biotechnology vs General Medicine'}, xlabel='Score shift $\\delta \\Phi_{\\tau}$ (%)', ylabel='Rank'>

# %%
# ADVERBS

import shifterator as sh

proportion_shift = sh.ProportionShift(type2freq_1=type2freq_1,
                                      type2freq_2=type2freq_2)

proportion_shift.get_shift_graph(system_names = ['Biotechnology', 'Medicine'],
                                 title='Biotechnology vs General Medicine')
# Out:
# c:\Users\uc_ma\AppData\Local\Programs\Python\Python38\lib\site-packages\shifterator\plotting.py:604: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x_ticks, fontsize=plot_params["xtick_fontsize"])
# <AxesSubplot:title={'center':'Biotechnology vs General Medicine'}, xlabel='Score shift $\\delta \\Phi_{\\tau}$ (%)', ylabel='Rank'>

# %%
# MODALS

entropy_shift = sh.EntropyShift(type2freq_1=type2freq_1,
                                type2freq_2=type2freq_2,
                                base=2)
entropy_shift.get_shift_graph(system_names = ['Biotechnology', 'Medicine'])
# Out:
# c:\Users\uc_ma\AppData\Local\Programs\Python\Python38\lib\site-packages\shifterator\plotting.py:604: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x_ticks, fontsize=plot_params["xtick_fontsize"])
# <AxesSubplot:title={'center':'Biotechnology: $\\Phi_{avg}=$2.23\nMedicine: $\\Phi_{avg}=$2.53'}, xlabel='Score shift $\\delta \\Phi_{\\tau}$ (%)', ylabel='Rank'>

# %%
# ADVERBS

entropy_shift = sh.EntropyShift(type2freq_1=type2freq_1,
                                type2freq_2=type2freq_2,
                                base=2)
entropy_shift.get_shift_graph(system_names = ['Biotechnology', 'Medicine'])
# Out:
# c:\Users\uc_ma\AppData\Local\Programs\Python\Python38\lib\site-packages\shifterator\plotting.py:604: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x_ticks, fontsize=plot_params["xtick_fontsize"])
# <AxesSubplot:title={'center':'Biotechnology: $\\Phi_{avg}=$6.11\nMedicine: $\\Phi_{avg}=$6.42'}, xlabel='Score shift $\\delta \\Phi_{\\tau}$ (%)', ylabel='Rank'>

# %%
# NOUNS

import shifterator as sh

proportion_shift = sh.ProportionShift(type2freq_1=type2freq_1,
                                      type2freq_2=type2freq_2)

proportion_shift.get_shift_graph(system_names = ['Biotechnology', 'Medicine'],
                                 title='Biotechnology vs General Medicine')
# Out:
# c:\Users\uc_ma\AppData\Local\Programs\Python\Python38\lib\site-packages\shifterator\plotting.py:604: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x_ticks, fontsize=plot_params["xtick_fontsize"])
# <AxesSubplot:title={'center':'Biotechnology vs General Medicine'}, xlabel='Score shift $\\delta \\Phi_{\\tau}$ (%)', ylabel='Rank'>

# %%
# NOUNS

entropy_shift = sh.EntropyShift(type2freq_1=type2freq_1,
                                type2freq_2=type2freq_2,
                                base=2)
entropy_shift.get_shift_graph(system_names = ['Biotechnology', 'Medicine'])
# Out:
# c:\Users\uc_ma\AppData\Local\Programs\Python\Python38\lib\site-packages\shifterator\plotting.py:604: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x_ticks, fontsize=plot_params["xtick_fontsize"])
# <AxesSubplot:title={'center':'Biotechnology: $\\Phi_{avg}=$9.93\nMedicine: $\\Phi_{avg}=$9.95'}, xlabel='Score shift $\\delta \\Phi_{\\tau}$ (%)', ylabel='Rank'>

# %%
entropy_shift = sh.EntropyShift(type2freq_1=type2freq_1,
                                type2freq_2=type2freq_2,
                                base=2)
entropy_shift.get_shift_graph(system_names = ['Biotechnology', 'Medicine'])
# Out:
# c:\Users\uc_ma\AppData\Local\Programs\Python\Python38\lib\site-packages\shifterator\plotting.py:604: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x_ticks, fontsize=plot_params["xtick_fontsize"])
# <AxesSubplot:title={'center':'Biotechnology: $\\Phi_{avg}=$7.72\nMedicine: $\\Phi_{avg}=$7.80'}, xlabel='Score shift $\\delta \\Phi_{\\tau}$ (%)', ylabel='Rank'>
